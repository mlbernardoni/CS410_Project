# %%
#import warnings
#warnings.filterwarnings('ignore')

from IPython.display import HTML
HTML('''<script>
 $('div.output_stderr').hide();
''')

# %run load_helper.ipynb


import pyLDAvis
import pyLDAvis.gensim  


# ##################################################
# Name the model to vis
#
#        baselines = ["10topics", "15topics", "20topics", "25topics", "30topics"]
#
#        or for an iteration
#        myiteration1
#
# once it loads, click or hover a circle to see the top terms#
#
# ##################################################
modelname = "20topics"
modelname = "30baseline2"


file_name = save_path + modelname + ".sav"
model = LdaModel.load(file_name)

pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(model, corpus, dictionary)
vis
# Out:
# Number of time slices with docs: 123
# Number of time slices: 123
# Number of time vocab: 12517
# Size of doctokens: 2673
# Number of documents: 2673
# 12517
# Number of unique tokens: 12517
# Pearsons correlation: 12517
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 3      0.054706 -0.014649       1        1  14.154170
# 19     0.028522  0.071940       2        1   9.070582
# 0     -0.009374  0.002970       3        1   7.197970
# 1     -0.082479 -0.021361       4        1   6.392061
# 8      0.020430  0.039804       5        1   5.308409
# 5     -0.120516 -0.013736       6        1   4.600731
# 15    -0.115817 -0.021583       7        1   4.543595
# 28     0.027106  0.022428       8        1   4.243411
# 9      0.029468 -0.029623       9        1   4.176463
# 11     0.022839  0.034831      10        1   3.841194
# 2      0.002822 -0.045085      11        1   3.763902
# 21    -0.139511 -0.012056      12        1   2.945037
# ...
